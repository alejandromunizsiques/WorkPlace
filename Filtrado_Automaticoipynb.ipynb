# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandromunizsiques/WorkPlace/blob/master/Filtrado_Automaticoipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Montaje Excel

# %%
excel_raw = pd.read_excel('/content/Filtros_2 para _Consolidado Facturas Pendientes 01 Enero al 15 Noviembre 2021.xlsx')
excel_raw.head()
# Out:
#    tipo       tipo_documento  ... llave2           Estado_Factura
# 0  34.0       factura_exenta  ...    NaN  OTRAS NO CONTABILIZADAS
# 1  34.0       factura_exenta  ...    NaN  OTRAS NO CONTABILIZADAS
# 2  34.0       factura_exenta  ...    NaN  OTRAS NO CONTABILIZADAS
# 3  33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 4  33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
#
# [5 rows x 56 columns]

# %% [markdown]
# # Filtros (NO TOCAR SIN PERMISO)

# %%
Excel_1  = excel_raw[(excel_raw.emisor == 968069802) & (excel_raw.receptor == "76.124.890-1")]
df1 = Excel_1[(Excel_1.monto_neto > 165585) & (Excel_1.monto_neto < 183015)]
#------------------------------------------------------------------------------------------------- # 968069802 ENTELPCSTELECOMUNICACIONESSA
Excel_2 = excel_raw[(excel_raw.emisor == 764660684) & (excel_raw.receptor == "90.635.000-9")] 
df2 = Excel_2[(Excel_2.monto_neto > 4592205) & (Excel_2.monto_neto < 5075595)]
#------------------------------------------------------------------------------------------------- # 76.466.068-4 Sociedad concesionaria nuevo pudahuel S.A
Excel_3 = excel_raw[(excel_raw.emisor == 767828004)& (excel_raw.receptor == "90.635.000-9")]
df3 = Excel_3[(Excel_3.monto_neto > 1425000) & (Excel_3.monto_neto < 1575000)]
#------------------------------------------------------------------------------------------------- # 76.782.800- 4 ASESORIA Y SERVICIOS INTEGRALES GOTTLIEB CARDINALI EIRL
Excel_4 = excel_raw[(excel_raw.emisor == 857838009) & (excel_raw.receptor == "76.124.890-1")]
df4 = Excel_4[(Excel_4.monto_neto > 61750) & (Excel_4.monto_neto < 68250)]
#------------------------------------------------------------------------------------------------- # 85.783.800-9 COMPLEJO MANUFACTURERO DE EQUIPOS TELEFONICOS S.A.C.I.
Excel_5 = excel_raw[(excel_raw.emisor == 889836008) & (excel_raw.receptor == "90.635.000-9")]
df5 = Excel_5[(Excel_5.monto_neto > 19928910) & (Excel_5.monto_neto < 22026690)]
#------------------------------------------------------------------------------------------------ # 88.983.600-8 GTD Teleductos S.A.
Excel_6 = excel_raw[(excel_raw.emisor == 902990003) & (excel_raw.receptor == "90.635.000-9")]
df6 = Excel_6[(Excel_6.monto_neto > 90744000) & (Excel_6.monto_neto < 100296000)]
#------------------------------------------------------------------------------------------------ # 90.299.000-3 Compania nacional de telefonos telefonica del sur
Excel_7 = excel_raw[(excel_raw.emisor == 902990004) & (excel_raw.receptor == "76.124.890-1") ]
df7 = Excel_7[(Excel_7.monto_neto > 593750) & (Excel_7.monto_neto < 656250)]
Excel_7_2 = excel_raw[(excel_raw.emisor == 902990004) & (excel_raw.receptor == "90.635.000-9")]
df7_2 = Excel_7_2[(Excel_7_2.monto_neto > 4560000) & (Excel_7_2.monto_neto < 5040000)]
#------------------------------------------------------------------------------------------------ # 90.299.000-4 Compania nacional de telefonos telefonica del sur
Excel_8 = excel_raw[(excel_raw.emisor == 925800007)& (excel_raw.receptor == "90.635.000-9")]
df8 = Excel_8[(Excel_8.monto_neto > 44284440) & (Excel_8.monto_neto < 48945960)]
#------------------------------------------------------------------------------------------------ # 92.580.000-7 Empresa Nacional de Telecomunicaciones S.A
Excel_9 = excel_raw[(excel_raw.emisor == 920470009) & (excel_raw.receptor == "90.635.000-9")]
df9 = Excel_9[(Excel_9.monto_neto > 61750) & (Excel_9.monto_neto < 68250)]
#------------------------------------------------------------------------------------------------ # 92047000-9 CIA DE TELEFONOS DE COYHAIQUE SA
Excel_10 = excel_raw[(excel_raw.emisor == 925800007) & (excel_raw.receptor == "90.635.000-9")]
df10_1 = Excel_10[(Excel_10.monto_neto > 19209000) & (Excel_10.monto_neto < 21231000)]
df10_2 = Excel_10[(Excel_10.monto_neto > 5130000) & (Excel_10.monto_neto < 5670000)]
Excel_10_1 = excel_raw[(excel_raw.emisor == 925800007) & (excel_raw.receptor == "76.124.890-1")]
df10_3 = Excel_10_1[(Excel_10_1.monto_neto > 11685000) & (Excel_10_1.monto_neto < 12915000)]
df10_4 = Excel_10_1[(Excel_10_1.monto_neto > 4446000) & (Excel_10_1.monto_neto < 4914000)]
#-------------------------------------------------------------------------------------------------# 92580000-7  EMPRESA NACIONAL DE TELECOMUNICACIONES S A
Excel_11 = excel_raw[(excel_raw.emisor == "94675000K") & (excel_raw.receptor == "90.635.000-9")] 
df11 = Excel_11[(Excel_11.monto_neto > 5130000) & (Excel_11.monto_neto < 5670000)]
#-------------------------------------------------------------------------------------------------#  94.675.000-K Claro Comunicaciones S.A
Excel_12 = excel_raw[(excel_raw.emisor == 967224006) & (excel_raw.receptor == "90.635.000-9")]
df12 = Excel_12[(Excel_12.monto_neto > 4873500) & (Excel_12.monto_neto < 5386500)]
#-------------------------------------------------------------------------------------------------# 96.722.400-6 PACIFICO CABLE SPA
Excel_13 = excel_raw[(excel_raw.emisor == "96756060-K") & (excel_raw.receptor == "90.635.000-9")]
df13 = Excel_13[(Excel_13.monto_neto > 135985654) & (Excel_13.monto_neto < 136212000)]
#-------------------------------------------------------------------------------------------------# 96.756.060-K COMUNICACION Y TELEFONIA RURAL S.A
Excel_14= excel_raw[(excel_raw.emisor == 9691073010) & (excel_raw.receptor == "90.635.000-9")]
df14 = Excel_14[(Excel_14.monto_neto > 2394000) & (Excel_14.monto_neto < 2646000)]
#--------------------------------------------------------------------------------------------------# 96910730-10 TELXIUS CABLE CHILE S.A.
Excel_15 = excel_raw[(excel_raw.emisor == 9691073011) & (excel_raw.receptor == "90.635.000-9")]
df15 = Excel_15[(Excel_15.monto_neto > 128250000) & (Excel_15.monto_neto < 141750000)]
#--------------------------------------------------------------------------------------------------# 96910730-11 TELXIUS CABLE CHILE S.A
Excel_16 = excel_raw[(excel_raw.emisor == 96910730-9) & (excel_raw.receptor == "90.635.000-9")]
df16 = Excel_16[(Excel_16.monto_neto > 15390000000) & (Excel_16.monto_neto < 17010000000)]
#---------------------------------------------------------------------------------------------------# 96910730-9 TELXIUS CABLE CHILE S.A.
Excel_17 = excel_raw[(excel_raw.emisor == 995056909) & (excel_raw.receptor == "90.635.000-9")]
df17 = Excel_17[(Excel_17.monto_neto > 11307660) & (Excel_17.monto_neto < 12497940)]
#---------------------------------------------------------------------------------------------------# 99.505.690-9 BLUE TWO CHILE S.A.

# %%
df17
# Out:
# Empty DataFrame
# Columns: [tipo, tipo_documento, Concatenar, Reclamada, Global, Excepcion, folio, Estado, emisor, razon_social_emisor, receptor, Soc, publicacion, emision, monto_neto, monto_exento, monto_iva, monto_total, Gestores Resp. , Area Resp., impuestos, estado_acepta, estado_sii, estado_intercambio, informacion_intercambio, uri_, referencias, mensaje_nar, uri_nar, uri_arm, fecha_arm, nmb_item, condicion_pago, controller, fecha_vencimiento, estado_cesion, url_correo_cesion, fecha_cesion, fecha_recepcion_sii, estado_reclamo_mercaderia, fecha_reclamo_mercaderia, estado_reclamo_contenido, fecha_reclamo_contenido, estado_nar, fecha_nar, mensaje_nar_, motivo_no_tramitacion, corresponde_gestion, acreedor, llave, a_contabilizar, Gestion, monto_total_duplicado, Fecha_RPA, llave2, Estado_Factura]
# Index: []

# %% [markdown]
# # Union datasets (NO TOCAR SIN PERMISO)

# %%
Excel_filtrado = pd.concat([df1,
                            df2,
                            df3,
                            df4,
                            df5,
                            df6,
                            df7,
                            df7_2,
                            df8,
                            df9,
                            df10_1,
                            df10_2,
                            df10_3,
                            df10_4,
                            df11,
                            df12,
                            df13,
                            df14,
                            df15,
                            df16,
                            df17])

# %% [markdown]
# # Display de dataframes unidos en una sola hoja

# %%
Excel_filtrado
# Out:
#       tipo       tipo_documento  ... llave2           Estado_Factura
# 2723  33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 2736  33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 653   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 76    33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 161   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 164   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 280   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 282   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 284   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 564   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 574   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 579   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# 376   33.0  factura_electronica  ...    NaN  OTRAS NO CONTABILIZADAS
# ...

# %%
Excel_filtrado.to_excel("prueba1.xlsx")
